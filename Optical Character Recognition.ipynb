# %% [markdown]
# DATA CLEANING

# %% [markdown]
# def clean_result(result):
#     det_text = []
#     for x in range(len(result)):
#         det_text.append(str(result[x][1]))
#     len_list = [i for i in range(len(det_text))]
#     det_text = dict(zip(len_list,det_text))
#     return det_text

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16
Image("Image.jpg")

# %%
reader = easyocr.Reader(['en'])
output = reader.readtext('Image.jpg')
output
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[192, 48], [719, 48], [719, 170], [192, 170]],
#   '(ertificate',
#   0.5774385608556178),
#  ([[330, 186], [572, 186], [572, 218], [330, 218]],
#   'This is to Certify that',
#   0.7832741807777319),
#  ([[245, 243], [661, 243], [661, 279], [245, 279]],
#   'MIs. Effistack India Pvt: Ltd:',
#   0.5075015045982675),
#  ([[141, 297], [762, 297], [762, 326], [141, 326]],
#   'Survcy No. 549/2, Shed No. 2 & 3, NH-8, Vill-Nana Fofaliya,',
#   0.4807199933369182),
#  ([[206, 324], [698, 324], [698, 352], [206, 352]],
#   'PO:: Kandari; Taluka:Dabhoi, Dist:: Vadodara,',
#   0.6777649355468909),
#  ([[330, 352], [418, 352], [418, 380], [330, 380]],
#   'Gujarat',
#   0.996693125785458),
#  ([[429, 348], [574, 348], [574, 378], [429, 378]],
#   '391210, India',
#   0.6919978999398179),
#  ([[214, 431], [686, 431], [686, 459], [214, 459]],
#   'has been found in Compliance with requirements of',
#   0.9440336461132829),
#  ([[215, 458], [687, 458], [687, 498], [215, 498]],
#   'Environmental Management System',
#   0.7197905901424364),
#  ([[156, 494], [742, 494], [742, 568], [156, 568]],
#   'ISO 14001:2015',
#   0.5262721724381093),
#  ([[326, 568], [570, 568], [570, 598], [326, 598]],
#   'for the following scope:',
#   0.9996004337806749),
#  ([[82, 622], [656, 622], [656, 650], [82, 650]],
#   'Design, Manufacturer; Supplier and Installation of Material',
#   0.7986723028229724),
#  ([[653, 617], [793, 617], [793, 653], [653, 653]],
#   'Handling and',
#   0.9999828279259709),
#  ([[78, 646], [792, 646], [792, 677], [78, 677]],
#   'Industrial Storage Systems, Industrial and Warehouse Automation System_',
#   0.9202544389062824),
#  ([[68, 670], [810, 670], [810, 703], [68, 703]],
#   'Warchouse Storage Equipment; Efficiency-Enhancing Solutions like Dynamic',
#   0.8032916773773048),
#  ([[53, 697], [616, 697], [616, 727], [53, 727]],
#   'Storage-Retrieval Machines and Shuttle Systems, Elevated',
#   0.9690507670555208),
#  ([[740, 697], [822, 697], [822, 729], [740, 729]],
#   'Storage',
#   0.9998014279802176),
#  ([[67, 722], [808, 722], [808, 755], [67, 755]],
#   'Platforms, Customized Pallets & Cages, Modular Enclosure, Roller Conveyor',
#   0.6337090024131129),
#  ([[82, 749], [796, 749], [796, 776], [82, 776]],
#   'and their Accessories, Dedicated Consulting Specialists for Development of',
#   0.869652132854277),
#  ([[98, 774], [780, 774], [780, 798], [98, 798]],
#   'Tailored Solutions and Custom Made Sheet Material Fabrication Work',
#   0.7696557223174573),
#  ([[66, 856], [182, 856], [182, 880], [66, 880]],
#   'Certificate No.',
#   0.918783467520119),
#  ([[284, 854], [478, 854], [478, 882], [284, 882]],
#   'EMS/012323/1019',
#   0.8393211690608543),
#  ([[66, 888], [264, 888], [264, 914], [66, 914]],
#   'Original Certificate Date',
#   0.7693848328133104),
#  ([[282, 888], [442, 888], [442, 912], [282, 912]],
#   '01-October-2019',
#   0.9929500865316739),
#  ([[65, 923], [157, 923], [157, 943], [65, 943]],
#   'Issue Date',
#   0.8015564545494039),
#  ([[281, 922], [442, 922], [442, 946], [281, 946]],
#   '01-October-2019',
#   0.625524047104803),
#  ([[609, 925], [739, 925], [739, 941], [609, 941]],
#   'Authorised Signature',
#   0.9252563985552036),
#  ([[512, 939], [830, 939], [830, 967], [512, 967]],
#   'Quality GontroL Certification',
#   0.5325832702618417),
#  ([[66, 954], [166, 954], [166, 980], [66, 980]],
#   'Expiry Date',
#   0.916798205344816),
#  ([[282, 956], [466, 956], [466, 982], [282, 982]],
#   '30-September-2022',
#   0.7530229207544571),
#  ([[569, 966], [773, 966], [773, 984], [569, 984]],
#   'UK Office: 1929, Chynowoth House',
#   0.7588362675928264),
#  ([[539, 981], [807, 981], [807, 995], [539, 995]],
#   'Trevissome Park, Truro-TRABUN; Cornwall; UK',
#   0.5914263041572232),
#  ([[111, 987], [385, 987], [385, 1007], [111, 1007]],
#   'To check this certificate status visit:',
#   0.781140007955032),
#  ([[565, 997], [781, 997], [781, 1015], [565, 1015]],
#   'India Office; Znd Floor; Aman Market,',
#   0.6227416415396172),
#  ([[71, 1004], [424, 1004], [424, 1028], [71, 1028]],
#   '"httplluasLuk comlcertifiedorganization html"',
#   0.6528452499869084),
#  ([[571, 1013], [687, 1013], [687, 1027], [571, 1027]],
#   'Narela Mandi, Delhi',
#   0.9780554587216987),
#  ([[693, 1013], [775, 1013], [775, 1027], [693, 1027]],
#   '110 040, India',
#   0.9796585415319479),
#  ([[532, 1118], [674, 1118], [674, 1144], [532, 1144]],
#   'ISO 14001+2015',
#   0.6473932935726794),
#  ([[247, 1151], [319, 1151], [319, 1171], [247, 1171]],
#   'UASL',
#   0.9926237463951111),
#  ([[229, 1171], [331, 1171], [331, 1183], [229, 1183]],
#   'ENVIRONMENTAL',
#   0.302065203954379),
#  ([[78, 1170], [185, 1170], [185, 1208], [78, 1208]],
#   'Sertiticanoo',
#   0.26277730082177),
#  ([[238, 1182], [322, 1182], [322, 1190], [238, 1190]],
#   'MANACeMFNT',
#   0.15104566656362314),
#  ([[87, 1217], [161, 1217], [161, 1229], [87, 1229]],
#   '"Quallty Control',
#   0.9755882548684487),
#  ([[164, 1218], [218, 1218], [218, 1226], [164, 1226]],
#   'Certification',
#   0.48190231607320005),
#  ([[219, 1215], [417, 1215], [417, 1229], [219, 1229]],
#   '(QCC)" accredlted by "UASL, England. UK"_',
#   0.27580658015101317),
#  ([[420, 1218], [486, 1218], [486, 1226], [420, 1226]],
#   'h/3 ceniticate',
#   0.20892744109004763),
#  ([[492, 1218], [524, 1218], [524, 1226], [492, 1226]],
#   'emains',
#   0.5263567858487174),
#  ([[528, 1218], [584, 1218], [584, 1226], [528, 1226]],
#   'the propely',
#   0.39695264953722165),
#  ([[601, 1215], [625, 1215], [625, 1229], [601, 1229]],
#   'Occ',
#   0.6015211062191407),
#  ([[642, 1218], [668, 1218], [668, 1226], [642, 1226]],
#   '"hom',
#   0.36244356632232666),
#  ([[680, 1218], [756, 1218], [756, 1226], [680, 1226]],
#   'mugt be returne @',
#   0.5003999467481656),
#  ([[772, 1218], [810, 1218], [810, 1226], [772, 1226]],
#   'request',
#   0.9707523445063712),
#  ([[619.0513167019495, 694.1539501058485],
#    [701.9498460149534, 703.4537322194531],
#    [697.9486832980505, 729.8460498941515],
#    [615.0501539850466, 719.5462677805469]],
#   'Racking',
#   0.9999962910744821),
#  ([[698.8905996075496, 702.3358994113244],
#    [740.7190717760413, 698.9778492142457],
#    [742.1094003924504, 720.6641005886756],
#    [700.2809282239587, 723.0221507857543]],
#   'and',
#   0.9998887099712829),
#  ([[577.3053712883528, 1071.1245024785526],
#    [641.9599746391641, 1079.60188015142],
#    [637.6946287116472, 1101.8754975214474],
#    [574.0400253608359, 1093.39811984858]],
#   '3ruIED',
#   0.019265228530495646),
#  ([[174.17239411139764, 1088.1792670450748],
#    [188.5089865985593, 1080.0658509254747],
#    [207.82760588860236, 1113.8207329549252],
#    [193.4910134014407, 1121.9341490745253]],
#   ';',
#   0.13177889204088444),
#  ([[358.30930882401475, 1130.0402397064163],
#    [506.5286770626656, 1090.1162701394792],
#    [514.6906911759852, 1124.9597602935837],
#    [366.4713229373344, 1164.8837298605208]],
#   'CERTIFIED',
#   0.9921043820398506)]
